# %% [markdown]
# # Ex1 - Filtering and Sorting Data

# %% [markdown]
# This time we are going to pull data directly from the internet.
# Special thanks to: https://github.com/justmarkham for sharing the dataset and materials.
#
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd
import numpy as np

data = pd.read_csv('https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv',sep = '\t')
data.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv).

# %% [markdown]
# ### Step 3. Assign it to a variable called chipo.

# %%
chipo = data
chipo.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98

# %% [markdown]
# ### Step 4. How many products cost more than $10.00?

# %%
convert = lambda x: float(x[1:-1])
#data['new_price'] = data.item_price.apply(convert)
#data[data.new_price > 10].shape[0]
data[(data.new_price > 10)&(data['quantity'] >1)]
# Out:
#       order_id  quantity              item_name  \
# 4            2         2           Chicken Bowl
# 135         60         2     Chicken Salad Bowl
# 148         67         2          Steak Burrito
# 150         68         2        Chicken Burrito
# 154         70         2           Chicken Bowl
# 213         94         2     Chicken Salad Bowl
# 217         96         2   Chicken Crispy Tacos
# 241        105         2        Chicken Burrito
# 281        123         2       Steak Salad Bowl
# 282        124         2           Chicken Bowl
# 315        137         2     Chicken Salad Bowl
# 353        152         2          Steak Burrito
# 354        153         2     Chicken Soft Tacos
# 409        178         3           Chicken Bowl
# 415        181         2           Chicken Bowl
# 426        185         2     Chicken Soft Tacos
# 445        193         3                   Bowl
# 506        212         2          Carnitas Bowl
# ...

# %% [markdown]
# ### Step 5. What is the price of each item?
# ###### print a data frame with only two columns item_name and item_price

# %%
data[['item_name','item_price']].head()
# Out:
#                                item_name item_price
# 0           Chips and Fresh Tomato Salsa     $2.39
# 1                                   Izze     $3.39
# 2                       Nantucket Nectar     $3.39
# 3  Chips and Tomatillo-Green Chili Salsa     $2.39
# 4                           Chicken Bowl    $16.98

# %% [markdown]
# ### Step 6. Sort by the name of the item

# %%
data.item_name.sort_values().head()
# Out:
# 3389    6 Pack Soft Drink
# 341     6 Pack Soft Drink
# 1849    6 Pack Soft Drink
# 1860    6 Pack Soft Drink
# 2713    6 Pack Soft Drink
# Name: item_name, dtype: object

# %% [markdown]
# ### Step 7. What was the quantity of the most expensive item ordered?

# %%
data.sort_values(by = 'new_price',ascending = False).head(1).reset_index().loc[0,'quantity']
# Out:
# 15

# %% [markdown]
# ### Step 8. How many times were a Veggie Salad Bowl ordered?

# %%
data1 = data.groupby('item_name').size().to_frame().reset_index()
data1.head()
data1[data1['item_name'] == 'Veggie Salad Bowl'].iloc[0,1]
# Out:
# 18

# %% [markdown]
# ### Step 9. How many times people orderd more than one Canned Soda?

# %%
data[(data['item_name'] =='Canned Soda')&(data['quantity'] >1)].count().order_id
# Out:
# 20
